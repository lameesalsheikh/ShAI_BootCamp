# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('/content/Salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#      Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134438 entries, 0 to 134437
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                134438 non-null  int64
#  1   EmployeeName      134438 non-null  object
#  2   JobTitle          134438 non-null  object
#  3   BasePay           133832 non-null  float64
#  4   OvertimePay       134437 non-null  float64
#  5   OtherPay          134437 non-null  float64
#  6   Benefits          98278 non-null   float64
#  7   TotalPay          134437 non-null  float64
#  8   TotalPayBenefits  134437 non-null  float64
#  9   Year              134437 non-null  float64
#  10  Notes             0 non-null       float64
#  11  Agency            134437 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 13.3+ MB

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                606
# OvertimePay              1
# OtherPay                 1
# Benefits             36160
# TotalPay                 1
# TotalPayBenefits         1
# Year                     1
# Notes               134438
# Agency                   1
# Status              134438
# dtype: int64

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  134438.000000  133832.000000  134437.000000  134437.000000
# mean    67219.500000   71012.763746    5531.427554    3919.977148
# std     38809.052082   41926.835921   11934.241965    8364.593533
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     33610.250000   46386.400000       0.000000       0.000000
# 50%     67219.500000   68270.945000       0.000000     990.860000
# 75%    100828.750000   98339.560000    5505.200000    4720.640000
# max    134438.000000  319275.010000  245131.880000  400184.250000
#
#            Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  98278.000000  134437.000000     134437.000000  134437.000000    0.0
# mean   27473.995834   80144.593317     100229.014737    2012.366410    NaN
# std    14513.456482   49789.794985      61894.072280       1.061009    NaN
# ...

# %%
#notes and stause are null values should drop these columns
df.drop(columns="Notes",axis=1,inplace=True)
df.drop(columns="Status",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#      Year         Agency
# 0  2011.0  San Francisco
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
# <ipython-input-9-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.036481    -0.020407 -0.055240 -0.136623
# BasePay          -0.036481  1.000000     0.241325  0.270715  0.907304
# OvertimePay      -0.020407  0.241325     1.000000  0.309867  0.270637
# OtherPay         -0.055240  0.270715     0.309867  1.000000  0.207834
# Benefits         -0.136623  0.907304     0.270637  0.207834  1.000000
# TotalPay         -0.051300  0.948320     0.497380  0.467800  0.867696
# TotalPayBenefits  0.092783  0.939509     0.458319  0.416867  0.918726
# Year              0.964824  0.212301     0.091210  0.047118  0.192846
#
#                   TotalPay  TotalPayBenefits      Year
# ...

# %%
#basePay and Total benefits are the same and total pay are same with Total pay benifts so should drop 2 colums depending on the correlation i will drop basepay and totalpaybenifits
df.drop(columns="BasePay",axis=1,inplace=True)
df.drop(columns="TotalPayBenefits",axis=1,inplace=True)

# %%
df_cat=df.select_dtypes(include="object")
df_cat
# Out:
#                   EmployeeName  \
# 0               NATHANIEL FORD
# 1                 GARY JIMENEZ
# 2               ALBERT PARDINI
# 3            CHRISTOPHER CHONG
# 4              PATRICK GARDNER
# ...                        ...
# 134433   Geraldine P Hernandez
# 134434          Myron L Bryant
# 134435         Matthew O Hogue
# 134436  Carolyn Karlegan-Muniz
# 134437         Michele Helgren
#
#                                               JobTitle         Agency
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  San Francisco
# 1                      CAPTAIN III (POLICE DEPARTMENT)  San Francisco
# 2                      CAPTAIN III (POLICE DEPARTMENT)  San Francisco
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  San Francisco
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  San Francisco
# ...                                                ...            ...
# 134433                                   Special Nurse  San Francisco
# ...

# %%
#unique values
for i in df_cat:
  df_cat[i].unique()
  print(len(df_cat[i].unique()))
# Out:
# 105699
# 2152
# 2

# %%
for i in df_cat:
  df_cat[i].value_counts()
  print((df_cat[i].value_counts()))
# Out:
# Kevin Lee          13
# Steven Lee         11
# William Wong       11
# Richard Lee        10
# KEVIN LEE           9
#                    ..
# Stephen Roche       1
# Michael Dearman     1
# Joshua Milstein     1
# Michael Whooley     1
# Anna Chenakina      1
# Name: EmployeeName, Length: 105699, dtype: int64
# Transit Operator                            6202
# Registered Nurse                            3591
# Special Nurse                               3096
# TRANSIT OPERATOR                            2388
# Police Officer 3                            2359
#                                             ...
# TRIAL DELAY REDUCTION COORDINATOR              1
# POWERHOUSE ELECTRICIAN SUPERVISOR II           1
# CHIEF NURSERY SPECIALIST                       1
# EMERGENCY PROTECTIVE ORDERS COMMISSIONER       1
# Gard                                           1
# Name: JobTitle, Length: 2152, dtype: int64
# San Francisco    134437
# Name: Agency, dtype: int64

# %%
top5=df['JobTitle'].value_counts().head(5)
top5.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df_num=df.select_dtypes(include="number")
df_num.columns
# Out:
# Index(['Id', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'Year'], dtype='object')

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134438 entries, 0 to 134437
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Id           134438 non-null  int64
#  1   OvertimePay  134437 non-null  float64
#  2   OtherPay     134437 non-null  float64
#  3   Benefits     98278 non-null   float64
#  4   TotalPay     134437 non-null  float64
#  5   Year         134437 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 6.2 MB

# %%
#missing value in benefits : i feel that it can fill by zero (HR issues) so maybe these are outside worker
df['Benefits']=df['Benefits'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Id              0
# EmployeeName    0
# JobTitle        0
# OvertimePay     1
# OtherPay        1
# Benefits        0
# TotalPay        1
# Year            1
# Agency          1
# dtype: int64

# %%
# Sample data creation
np.random.seed(0)

# Plotting Histogram with KDE and Boxplot for each numerical feature
fig, axes = plt.subplots(len(df_num.columns), 2, figsize=(12, 5 * len(df_num.columns)))

for i, col in enumerate(df_num.columns):
    # Histogram with KDE
    df_num[col].plot(kind='hist', density=True, ax=axes[i, 0], bins=20, alpha=0.5, color='blue')
    df_num[col].plot(kind='kde', ax=axes[i, 0], color='red')
    axes[i, 0].set_title(f'{col} - Histogram with KDE')

    # Boxplot
    df_num.boxplot(column=col, ax=axes[i, 1])
    axes[i, 1].set_title(f'{col} - Boxplot')

plt.tight_layout()
plt.show()

# %%
#Id is sequancal (just index)
#overtime skewed to the left and there is many outliers
#otherpay same as overtime
#benefits is nearly normal dstribution (skewed to left)
#also toalpay same to benifits (skewed to left)
#year should be categorical

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['TotalPay'], kde=True, color='skyblue')
plt.title('Histogram and KDE for Total Pay')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# %%
#the data skewed to the left (need maxmin scaler)

# %%
avg=df.groupby('Year').mean()['TotalPay']
avg.plot(kind = 'bar')
# Out:
# <ipython-input-17-11e6fcdf5085>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg=df.groupby('Year').mean()['TotalPay']
# <Axes: xlabel='Year'>

# %%
plt.figure(figsize=(10, 6))
heatmap_data = df.corr()
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='g')
plt.title('Heatmap of Data farame')
plt.show()
# Out:
# <ipython-input-18-0fca95895e00>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap_data = df.corr()

# %% [markdown]
# # Good Luck!
